# %%
import numpy as np
import matplotlib.pyplot as plt

def sunburst(nodes, total=np.pi * 2, offset=0, level=0, ax=None, image_name="sunbeam_chart_unknown.png", dpi_=500):
    ax = ax or plt.subplot(111, projection='polar')

    if level == 0 and len(nodes) == 1:
        label, value, subnodes = nodes[0]
        ax.bar([0], [0.5], [np.pi * 2])
        ax.text(0, 0, label, ha='center', va='center')
        sunburst(subnodes, total=value, level=level + 1, ax=ax)
    elif nodes:
        d = np.pi * 2 / total
        labels = []
        widths = []
        local_offset = offset
        for label, value, subnodes in nodes:
            labels.append(label)
            widths.append(value * d)
            sunburst(subnodes, total=total, offset=local_offset,
                     level=level + 1, ax=ax)
            local_offset += value
        values = np.cumsum([offset * d] + widths[:-1])
        heights = [1] * len(nodes)
        bottoms = np.zeros(len(nodes)) + level - 0.5
        rects = ax.bar(values, heights, widths, bottoms, linewidth=1,
                       edgecolor='white', align='edge')
        for rect, label in zip(rects, labels):
            x = rect.get_x() + rect.get_width() / 2
            y = rect.get_y() + rect.get_height() / 2
            rotation = (90 + (360 - np.degrees(x) % 180)) % 360
            ax.text(x, y, label, rotation=rotation, ha='center', va='center',fontsize=5) 

    if level == 0:
        ax.set_theta_direction(-1)
        ax.set_theta_zero_location('N')
        ax.set_axis_off()
    plt.savefig(image_name, dpi=dpi_)

# %%
data = [
    ('Vlorë', 100, [
        ('Largim', 21*100/34, [
            ('MZHU 1', 100/34, []),
            ('MZHU 2', 100/34, []),
            ('MZHU 3', 100/34, []),
            ('MZHU 4', 100/34, []),
            ('MZHU 5', 100/34, []),
            ('MZHU 6', 100/34, []),
            ('Sarandë Vollodër', 100/34, []),
            ('MZHU 7', 100/34, []),
            ('Selenicë', 100/34, []),
            ('Kocul', 100/34, []),
            ('Sevaster', 100/34, []),
            ('Kote', 100/34, []),
            ('Selenicë MZHU', 100/34, []),
            ('Narte', 100/34, []),
            ('MZHU 8', 100/34, []),
            ('MZHU 9', 100/34, []),
            ('MZHU 10', 100/34, []),
            ('MZHU 11', 100/34, []),
            ('MZHU 12', 100/34, []),
            ('MZHU 13', 100/34, []),
            ('MZHU 14', 100/34, []),
        ]),
        ('Mbyllje', 13*100/34, [
            ('Delvinë MZHU', 100/34, []),
            ('Visha', 100/34, []),
            ('Konispol', 100/34, []),
            ('Konispol MZHU', 100/34, []),
            ('Finiq', 100/34, []),
            ('Selenicë MZHU', 100/34, []),
            ('Xhyherinë', 100/34, []),
            ('Novoselë', 100/34, []),
            ('Vlorë', 100/34, []),
            ('Orikum', 100/34, []),
            ('Shushicë', 100/34, []),
            ('Sherishte', 100/34, []),
            ('Zvernec', 100/34, []),
        ]),
    ]),
]

# %%
sunburst(data, image_name="Lezha.png", dpi_=500, total=np.pi * 2, offset=0, level=0)

# %%
data = [
    ('Berat', 100, [
        ('Rehabilitim', 8*100/25, [
            ('Ish Ferma Partizani', 100/25, []),
            ('Gropat e Bitumit', 100/25, []),
            ('Lagjia Plirez Nr1', 100/25, []),
            ('Lagjia Plirez Nr2', 100/25, []),
            ('Çorovodë Nr1', 100/25, []),
            ('Çorovodë mbetje urbane', 100/25, []),
            ('Vokopole', 100/25, []),
            ('Lagjia 28 Nëntori', 100/25, []),
        ]),
        ('Largim', 9*100/25, [
            ('VD Nr1', 100/25, []),
            ('VD Nr4', 100/25, []),
            ('VD Nr5', 100/25, []),
            ('VD Nr6', 100/25, []),
            ('VD Nr7', 100/25, []),
            ('VD Nr8', 100/25, []),
            ('Fshati Sqepur', 100/25, []),
            ('Fshati Kuç', 100/25, []),
            ('VD MZHU 1', 100/25, []),
        ]),
        ('Mbyllje', 7*100/25, [
            ('Dushnik', 100/25, []),
            ('Lagjia Çlirim', 100/25, []),
            ('Qëndra Lira', 100/25, []),
            ('Bogove Nr1', 100/25, []),
            ('Bogove Nr2', 100/25, []),
            ('Çerenishte', 100/25, []),
            ('MZHU 2', 100/25, []),
        ]),
        ('Mbjellje pemësh', 1*100/25, [
            ('Ish Venddepozitim', 100/25, []),
        ]),
    ]),
]

# %%
sunburst(data, image_name="Berat.png", dpi_=500, total=np.pi * 2, offset=0, level=0)

# %%
data = [
    ('Elbasan', 100, [
        ('Rehabilitim', 5*100/17, [
            ('Shkëmbi Zekthit', 100/17, []),
            ('Kusha', 100/17, []),
            ('Fshati Mashan', 100/17, []),
            ('Peqin', 100/17, []),
            ('Krastë', 100/17, []),
        ]),
        ('Largim', 8*100/17, [
            ('Cërrik', 100/17, []),
            ('Gostim', 100/17, []),
            ('Mollas', 100/17, []),
            ('Klos', 100/17, []),
            ('Shales', 100/17, []),
            ('Pisha Lagjia Çame', 100/17, []),
            ('Balez', 100/17, []),
            ('Rrypzat e Lushit', 100/17, []),
        ]),
        ('Mbyllje', 4*100/17, [
            ('Muriqan', 100/17, []),
            ('Fshati Vidhas', 100/17, []),
            ('MZHU 1', 100/17, []),
            ('Qukës', 100/17, []),
        ]),
    ]),
]

# %%
sunburst(data, image_name="Elbasan.png", dpi_=500, total=np.pi * 2, offset=0, level=0)

# %%
data = [
    ('Fier', 100, [
        ('Largim', 5*100/18, [
            ('Divjakë', 100/18, []),
            ('MZHU 1', 100/18, []),
            ('MZHU 2', 100/18, []),
            ('MZHU 3', 100/18, []),
            ('Roskovec', 100/18, []),
        ]),
        ('Rehabilitim', 7*100/18, [
            ('Gur Remas', 100/18, []),
            ('Teodori Muzaka', 100/18, []),
            ('Lushnje', 100/18, []),
            ('Kash Mallakastër', 100/18, []),
            ('Mazarent', 100/18, []),
            ('Zharrëz', 100/18, []),
            ('Fshati Marinez', 100/18, []),
        ]),
        ('Mbyllje', 6*100/18, [
            ('Gradisht', 100/18, []),
            ('Tërbuf', 100/18, []),
            ('Grabian', 100/18, []),
            ('Dushk', 100/18, []),
            ('Krutje', 100/18, []),
            ('Bubullimë', 100/18, []),
        ]),
    ]),
]

# %%
sunburst(data, image_name="Fier.png", dpi_=500, total=np.pi * 2, offset=0, level=0)

# %%
data = [
    ('Tiranë', 100, [
        ('Largim', 15*100/30, [
            ('Kavajë', 100/30, []),
            ('Ura Rrogozhinë', 100/30, []),
            ('Rrogozhinë', 100/30, []),
            ('Gosë', 100/30, []),
            ('Kashar', 100/30, []),
            ('Ura në Pezë', 100/30, []),
            ('Ura e Mezezit', 100/30, []),
            ('Arbane', 100/30, []),
            ('Ferraj', 100/30, []),
            ('Ibë', 100/30, []),
            ('Mjullbathore', 100/30, []),
            ('Prush Vaqarr', 100/30, []),
            ('Picalle', 100/30, []),
            ('Linzë', 100/30, []),
            ('Bulticë', 100/30, []),
        ]),
        ('Rehabilitim', 2*100/30, [
            ('MZHU 1', 100/30, []),
            ('Kuç', 100/30, []),
        ]),
        ('Mbyllje', 13*100/30, [
            ('MZHU 2', 100/30, []),
            ('MZHU 3', 100/30, []),
            ('MZHU 4', 100/30, []),
            ('MZHU 5', 100/30, []),
            ('Sharrdushk', 100/30, []),
            ('Ura Damjan', 100/30, []),
            ('Menik', 100/30, []),
            ('Ura e Beshirit', 100/30, []),
            ('Mezez', 100/30, []),
            ('Ura e Brarit', 100/30, []),
            ('Krrabë', 100/30, []),
            ('Baldushk', 100/30, []),
            ('Vishaj', 100/30, []),
        ]),
    ]),
]

# %%
sunburst(data, image_name="Tirane.png", dpi_=500, total=np.pi * 2, offset=0, level=0)

# %%
data = [
    ('Korçë', 100, [
        ('Largim', 4*100/19, [
            ('Zrnosko', 100/19, []),
            ('Dollna Gorica', 100/19, []),
            ('Gorna Gorica', 100/19, []),
            ('Tumenic', 100/19, []),
        ]),
        ('Rehabilitim', 3*100/19, [
            ('Leskovik', 100/19, []),
            ('Korçë', 100/19, []),
            ('Pustec', 100/19, []),
        ]),
        ('Mbyllje', 12*100/19, [
            ('Gurët e zinj', 100/19, []),
            ('Miras', 100/19, []),
            ('Baban stropan', 100/19, []),
            ('Ersekë', 100/19, []),
            ('Bulgarec', 100/19, []),
            ('Mollaj', 100/19, []),
            ('Voskopojë', 100/19, []),
            ('Sovjan', 100/19, []),
            ('Maliq', 100/19, []),
            ('Zvezdë', 100/19, []),
            ('Luadhi i Çelos', 100/19, []),
            ('Përroi i Shtogut', 100/19, []),
        ]),
    ]),
]

# %%
sunburst(data, image_name="Korce.png", dpi_=500, total=np.pi * 2, offset=0, level=0)

# %%
data = [
    ('Gjirokastër', 100, [
        ('Largim', 1*100/8, [
            ('Ura e Glinës', 100/8, []),
        ]),
        ('Rehabilitim', 7*100/8, [
            ('Gerhot', 100/8, []),
            ('Variboh', 100/8, []),
            ('Kodra e Doftis', 100/8, []),
            ('Cepi i Janinave', 100/8, []),
            ('Braçkovë', 100/8, []),
            ('Varrezat Publike', 100/8, []),
            ('Majkosh', 100/8, []),
        ]),
    ]),
]

# %%
sunburst(data, image_name="Gjirokaster.png", dpi_=500, total=np.pi * 2, offset=0, level=0)

# %%
data = [
    ('Durrës', 100, [
        ('Mbyllje', 8*100/9, [
            ('Porto Romano', 100/9, []),
            ('Vadadhe', 100/9, []),
            ('Gryk Minierë', 100/9, []),
            ('Fushë Biz ', 100/9, []),
            ('Ishëm', 100/9, []),
            ('Kameras', 100/9, []),
            ('Kraste', 100/9, []),
            ('VD MZHU', 100/9, []),
         ]),
        ('Rehabilitim', 1*100/9, [
            ('Dukagjin', 100/9, []),
        ]),
    ]),
]

# %%
sunburst(data, image_name="Durres.png", dpi_=500, total=np.pi * 2, offset=0, level=0)

# %%
data = [
    ('Dibër', 100, [
        ('Largim', 5*100/12, [
            ('Ura Pesjakës', 100/12, []),
            ('Muhurr', 100/12, []),
            ('Rabdisht', 100/12, []),
            ('Përroi Gjelagjosh', 100/12, []),
            ('Kastriot Kuke', 100/12, []),
        ]),
        ('Rehabilitim', 5*100/12, [
            ('Qafa e Buallit', 100/12, []),
            ('Ostren', 100/12, []),
            ('Krast', 100/12, []),
            ('Cërruj', 100/12, []),
            ('Burrel', 100/12, []),
        ]),
        ('Mbyllje', 1*100/12, [
            ('Ura e Ulzës', 100/12, []),
        ]),
        ('I rehabilituar', 1*100/12, [
            ('Llasen', 100/12, []),
        ]),
    ]),
]

# %%
sunburst(data, image_name="Diber.png", dpi_=500, total=np.pi * 2, offset=0, level=0)

# %%
data = [
    ('Lezhë', 100, [
        ('Largim', 3*100/7, [
            ('Ilegal Ndërfushas', 100/7, []),
            ('Lumi Zmeja', 100/7, []),
            ('Lumi Fan', 100/7, []),
        ]),
        ('Rehabilitim', 1*100/7, [
            ('Lagjia Nene Tereza', 100/7, []),
        ]),
        ('Mbyllje', 1*100/7, [
            ('Koder Kolc', 100/7, []),
        ]),
        ('I rehabilituar', 2*100/7, [
            ('Legal i vjetër Ndërfushas', 100/7, []),
            ('Legal i ri Ndërfushas', 100/7, []),
        ]),
    ]),
]

# %%
sunburst(data, image_name="Lezhe.png", dpi_=500, total=np.pi * 2, offset=0, level=0)

# %%
data = [
    ('Kukës', 100, [
        ('Largim', 34, [
            ('Fierzë', 17, []),
            ('Lekbibaj', 17, []),
        ]),
        ('Rehabilitim', 48, [
            ('VD Nr 1', 16, []),
            ('Myc Mamez', 16, []),
            ('Koj', 16, []),
        ]),
        ('Mbyllje', 18, [
            ('Bozhe', 18, []),
        ]),
    ]),
]

# %%
sunburst(data, image_name="Kukes.png", dpi_=500, total=np.pi * 2, offset=0, level=0)

# %%
data = [
    ('WZ_Dibër', 100, [
        ('Bulqizë', 3*100/12, [
            ('Rehabilitim', 3*100/12, [
                ('Qafa e Buallit', 100/12, []),
                ('Ostren', 100/12, []),
                ('Krast', 100/12, []),
             ]),
        ]),
         ('Dibër', 6*100/12, [
             ('Largim', 5*100/12, [
                 ('Ura Pesjakës', 100/12, []),
                 ('Muhurr', 100/12, []),
                 ('Rabdisht', 100/12, []),
                 ('Përroi Gjelagjosh', 100/12, []),
                 ('Kastriot Kuke', 100/12, []),
             ]),
             ('I rehabilituar', 1*100/12, [
                 ('Llasen', 100/12, []),
             ]),
        ]),
         ('Klos', 1*100/12, [
             ('Rehabilitim', 1*100/12, [
                 ('Cërruj', 100/12, []),
             ]),
        ]),
        ('Mat', 2*100/12, [
            ('Rehabilitim', 1*100/12, [
                ('Burrel', 100/12, []),
            ]),
            ('Mbyllje', 1*100/12, [
                ('Ura e Ulzës', 100/12, []),
            ]),
        ]),
    ]),
]

# %%
sunburst(data, image_name="Kukes.png", dpi_=500, total=np.pi * 2, offset=0, level=0)
